# %%
#first, we always import the necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

# %%
#we then have to import the data set from downloads
df = pd.read_csv(R'C:\Users\hanna\Downloads\archive (1).zip')

# %%
#call the data set to ensure it is working
df
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)
# 0              1    Male   19              15000                      39  \
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
#we then need to assess the data
#the head() function gives a quic picture of what it looks like
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)
# 0           1    Male   19              15000                      39  \
# 1           2    Male   21              35000                      81
# 2           3  Female   20              86000                       6
# 3           4  Female   23              59000                      77
# 4           5  Female   31              38000                      40
#
#       Profession  Work Experience  Family Size
# 0     Healthcare                1            4
# 1       Engineer                3            3
# 2       Engineer                1            1
# 3         Lawyer                0            2
# 4  Entertainment                2            6

# %% [markdown]
# - We have a numerical column called CustomerID
# - Categorical column called Gender
# - Numerical column called Age
# - Numerical column called Annual Income
# - Numerical column called Spending Score, probably based on how much/how often they spend
# - Categorical column called Profession, this details what job each customer has
# - Numerical column called Work Experience, we will assume this is in years
# - Numerical column called Family Size, describing how many people are in their family

# %%
#next, use the info() function to assess structural issues
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              2000 non-null   int64
#  1   Gender                  2000 non-null   object
#  2   Age                     2000 non-null   int64
#  3   Annual Income ($)       2000 non-null   int64
#  4   Spending Score (1-100)  2000 non-null   int64
#  5   Profession              1965 non-null   object
#  6   Work Experience         2000 non-null   int64
#  7   Family Size             2000 non-null   int64
# dtypes: int64(6), object(2)
# memory usage: 125.1+ KB

# %% [markdown]
# As we can see, there are 2000 entries.
# - The only column that is missing data is the profession column, with 1965/2000 entries

# %%
#next, use the describe() function to see initial descriptive statistics of the data. Use include = 'all' if there is categorical data.
df.describe(include = 'all')
# Out:
#          CustomerID  Gender          Age  Annual Income ($)
# count   2000.000000    2000  2000.000000        2000.000000  \
# unique          NaN       2          NaN                NaN
# top             NaN  Female          NaN                NaN
# freq            NaN    1186          NaN                NaN
# mean    1000.500000     NaN    48.960000      110731.821500
# std      577.494589     NaN    28.429747       45739.536688
# min        1.000000     NaN     0.000000           0.000000
# 25%      500.750000     NaN    25.000000       74572.000000
# 50%     1000.500000     NaN    48.000000      110045.000000
# 75%     1500.250000     NaN    73.000000      149092.750000
# max     2000.000000     NaN    99.000000      189974.000000
#
#         Spending Score (1-100) Profession  Work Experience  Family Size
# count              2000.000000       1965      2000.000000  2000.000000
# unique                     NaN          9              NaN          NaN
# ...

# %% [markdown]
# Some initial observations that can be made include:
# - There are 9 unique positions, with 'artist' being the most frequently occurring (612/1965 = ~30% of data available)
# - Female is the most frequently occuring gender (~60%) with 1186/2000 occurrences
# - The mean and median annual income are very similar, indicating a normal distribution
# - The same holds true for spending score

# %% [markdown]
# For data cleaning:
# - There are no issues with the type of data in any of the columns (ex: if a date column was 'object' it would need to be changed to 'datetime')
# - For normally distributed columns, it is ok to use the mean() to fill in any missing values, or use mean grouped by other things (ex: profession, family size)
# - Mode can create bias if it does not account for a large amount of the data, can fill in those values with 'Other' or randomly
